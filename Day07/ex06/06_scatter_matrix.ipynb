# %%
import sqlite3
import pandas as pd
from pandas.plotting import scatter_matrix
try:
    sqlite_connection = sqlite3.connect('../data/checking-logs.sqlite.sqlite')
    print('УСПЕШНО')
except sqlite3.Error as error:
    print("Ошибка при подключении к sqlite", error)
# Out:
# УСПЕШНО

# %% [markdown]
# выдергиваем нужную инфу из пайджа

# %%
request = '''
SELECT uid, COUNT(*) AS pageviews
FROM pageviews
WHERE uid LIKE 'user_%'
GROUP BY uid
'''
views = pd.io.sql.read_sql(request, sqlite_connection, parse_dates=['datetime'])
views
# Out:
#         uid  pageviews
# 0    user_1         28
# 1   user_10         89
# 2   user_14        143
# 3   user_17         47
# 4   user_18          3
# 5   user_19         16
# 6   user_21         10
# 7   user_25        179
# 8   user_28        149
# 9    user_3        317
# 10  user_30          3
# 11   user_5          1
# 12   user_9          2

# %% [markdown]
# выдергиваем нужную инфу из чекера

# %%
request = '''
SELECT uid, COUNT(*) AS num_commits
FROM checker
WHERE uid LIKE 'user_%'
AND labname != 'project1'
GROUP BY uid
'''
commits = pd.io.sql.read_sql(request, sqlite_connection, parse_dates=['timestamp'])
commits
# Out:
#         uid  num_commits
# 0    user_0            3
# 1    user_1           62
# 2   user_10           20
# 3   user_11            7
# 4   user_12           86
# 5   user_13           52
# 6   user_14           61
# 7   user_15           23
# 8   user_16           41
# 9   user_17           51
# 10  user_18            5
# 11  user_19          118
# 12   user_2           46
# 13  user_20           57
# 14  user_21           65
# 15  user_22            5
# 16  user_23            6
# 17  user_24           37
# 18  user_25           79
# 19  user_26           36
# 20  user_27           27
# 21  user_28           60
# 22  user_29           51
# 23   user_3           18
# 24  user_30           34
# 25  user_31          128
# 26   user_4           40
# 27   user_6           15
# 28   user_7            8
# 29   user_8           71

# %% [markdown]
# ищем разницу во времени заменяем пропуски груперуем и делаем табличку

# %%
request = '''
SELECT checker.uid,
       checker.labname, 
       checker.timestamp AS first_commit_ts, 
       pageviews.datetime AS first_view_ts
FROM checker 
LEFT JOIN pageviews ON checker.uid=pageviews.uid
WHERE status='ready'
      AND numTrials=1
      AND labname IN ('laba04', 'laba04s', 'laba05','laba06', 'laba06s')
      AND checker.uid LIKE 'user_%'
      AND (pageviews.datetime = (SELECT MIN(pageviews.datetime)
                                 FROM pageviews
                                 WHERE uid=checker.uid
                                 )
                                 OR pageviews.datetime IS NULL
            )
'''
df = pd.io.sql.read_sql(request, sqlite_connection, parse_dates=[
                        'first_commit_ts', 'first_view_ts'])
df = df[df['first_view_ts'].notna()].reset_index(drop=True)
df['avg_diff'] = ((df['first_view_ts'] - df['first_commit_ts']
                   ).dt.total_seconds()).div(3600)
df = df.groupby(['uid']).mean(numeric_only=True)['avg_diff'].reset_index()
df = df.merge(views, how='inner', on='uid').merge(
    commits, how='inner', on='uid')
df
# Out:
#         uid    avg_diff  pageviews  num_commits
# 0    user_1 -239.380182         28           62
# 1   user_10 -430.826806         89           20
# 2   user_14 -101.533075        143           61
# 3   user_17 -445.243366         47           51
# 4   user_18  -50.807026          3            5
# 5   user_19 -402.048859         16          118
# 6   user_21 -211.211785         10           65
# 7   user_25  102.990101        179           79
# 8   user_28  117.524583        149           60
# 9    user_3   78.234742        317           18
# 10  user_30 -281.697069          3           34

# %% [markdown]
# делаем графики на основе данных

# %%
ax = scatter_matrix(df,
                    figsize=(15, 8),
                    diagonal='kde',
                    density_kwds=dict(color='#059ABF', linewidth=3),
                    s=200,
                    color='red')

# %% [markdown]
# Can we say that if a user has a low number of pageviews then they likely have a low number of commits? no
#
# Can we say that if a user has a low number of pageviews then they likely have a small average difference between the first commit and the lab deadline? no
#
# Can we say that there are many users with a low number of commits and a few with a high number of commits? yes
#
# Can we say that there are many users with a small average difference and a few with a large average difference no

# %%
sqlite_connection.close()
